# %%
import numpy as np
import pandas as pd
import librosa

from tensorflow import keras
import tensorflow as tf

# %%
TRAIN_PATH = "C:\\Users\\alexc\\Downloads\\test.csv"
train_set = pd.read_csv(TRAIN_PATH)

# %%
train_set.head()
# Out:
#    Unnamed: 0          0          1          2          3          4  \
# 0           0 -19.299429  23.939819  24.920246  23.824490  18.229757
# 1           1  -2.189797  -4.726838  -4.758101  -4.723190  -4.708518
# 2           2  -2.980991  -4.713631  -4.737583  -4.757959  -4.772906
# 3           3  -2.779949  -4.730165  -4.758700  -4.763338  -4.764628
# 4           4  -2.869667  -4.640110  -4.657211  -4.674681  -4.685334
#
#            5         6         7         8  ...  3450  3451  3452  3453  3454  \
# 0  12.041117  7.927525  5.685409  5.893334  ...   NaN   NaN   NaN   NaN   NaN
# 1  -4.675638 -4.688027 -4.726974 -4.715340  ...   NaN   NaN   NaN   NaN   NaN
# 2  -4.783252 -4.787738 -4.792071 -4.795683  ...   NaN   NaN   NaN   NaN   NaN
# 3  -4.769955 -4.767997 -4.771176 -4.771989  ...   NaN   NaN   NaN   NaN   NaN
# 4  -4.692846 -4.694382 -4.692058 -4.683984  ...   NaN   NaN   NaN   NaN   NaN
#
#    3455  3456  3457  3458  3459
# 0   NaN   NaN   NaN   NaN   NaN
# ...

# %%
train_set.describe()
# Out:
#        Unnamed: 0            0            1            2            3  \
# count  4096.00000  4096.000000  4096.000000  4096.000000  4096.000000
# mean   2047.50000    -3.097151    -4.493268    -4.458583    -4.456036
# std    1182.55768     2.231695     4.226259     3.875606     3.441366
# min       0.00000   -35.420773   -46.602238   -38.250286   -31.240702
# 25%    1023.75000    -4.401959    -4.908533    -4.926726    -4.932182
# 50%    2047.50000    -3.015331    -4.422704    -4.451975    -4.463307
# 75%    3071.25000    -1.524805    -3.476279    -3.512964    -3.519183
# max    4095.00000     0.431614    28.684881    27.457111    23.824490
#
#                  4            5            6            7            8  ...  \
# count  4096.000000  4096.000000  4096.000000  4096.000000  4096.000000  ...
# mean     -4.509934    -4.478107    -4.489681    -4.509299    -4.517042  ...
# std       3.146592     2.750860     2.574419     2.469622     2.395947  ...
# ...
